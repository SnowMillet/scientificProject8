# %%
import os


class Para:
    read_folder_path = 'data/zs_space_1d_rate_20d_22-22_raw'
    write_folder_path = 'data/zs_space_1d_rate_20d_22-22_pre'

    feature_column_start_name = 'ep_ratio_ttm'
    feature_column_end_name = 'BR'

    month_num = len(os.listdir(read_folder_path))
para = Para()
print(para.month_num)
# Out:
# 31

# %%
import time
import numpy as np
import pandas as pd


time_begin = time.time()

df = pd.DataFrame()

for i_csv in range(para.month_num):

    df_curr_month = pd.read_csv(para.read_folder_path +'/'+ str(i_csv) + '.csv', index_col='order_book_id')

    df_curr_month['date'] = pd.to_datetime(df_curr_month['date'])

    df = pd.concat([df, df_curr_month])

df
# Out:
#               board_type sector_code  yield_rate  month       date  \
# order_book_id
# 600036.XSHG    MainBoard  Financials    0.069493      0 2022-01-04
# 600036.XSHG    MainBoard  Financials    0.052396      1 2022-01-05
# 600036.XSHG    MainBoard  Financials    0.073936      2 2022-01-06
# 600036.XSHG    MainBoard  Financials    0.075637      3 2022-01-07
# 600036.XSHG    MainBoard  Financials    0.040016      4 2022-01-10
# 600036.XSHG    MainBoard  Financials    0.007422      5 2022-01-11
# 600036.XSHG    MainBoard  Financials    0.026326      6 2022-01-12
# 600036.XSHG    MainBoard  Financials    0.042967      7 2022-01-13
# 600036.XSHG    MainBoard  Financials    0.084132      8 2022-01-14
# 600036.XSHG    MainBoard  Financials    0.065459      9 2022-01-17
# 600036.XSHG    MainBoard  Financials    0.045093     10 2022-01-18
# 600036.XSHG    MainBoard  Financials    0.022736     11 2022-01-19
# 600036.XSHG    MainBoard  Financials   -0.026280     12 2022-01-20
# 600036.XSHG    MainBoard  Financials   -0.038788     13 2022-01-21
# 600036.XSHG    MainBoard  Financials   -0.039537     14 2022-01-24
# 600036.XSHG    MainBoard  Financials   -0.012967     15 2022-01-25
# 600036.XSHG    MainBoard  Financials   -0.030000     16 2022-01-26
# 600036.XSHG    MainBoard  Financials   -0.020485     17 2022-01-27
# 600036.XSHG    MainBoard  Financials   -0.010364     18 2022-01-28
# 600036.XSHG    MainBoard  Financials   -0.089387     19 2022-02-07
# 600036.XSHG    MainBoard  Financials   -0.120480     20 2022-02-08
# 600036.XSHG    MainBoard  Financials   -0.140062     21 2022-02-09
# 600036.XSHG    MainBoard  Financials   -0.135564     22 2022-02-10
# 600036.XSHG    MainBoard  Financials   -0.157506     23 2022-02-11
# 600036.XSHG    MainBoard  Financials   -0.176758     24 2022-02-14
# 600036.XSHG    MainBoard  Financials   -0.214456     25 2022-02-15
# 600036.XSHG    MainBoard  Financials   -0.166242     26 2022-02-16
# 600036.XSHG    MainBoard  Financials   -0.135056     27 2022-02-17
# 600036.XSHG    MainBoard  Financials   -0.113139     28 2022-02-18
# 600036.XSHG    0.285640  0.949980  1.787979  77.660972   86.717137
# 600036.XSHG    0.286527  0.915528  1.806222  71.508380   79.650032
# 600036.XSHG    0.286630  0.864869  1.789657  64.498141   73.890339
# 600036.XSHG    0.286576  0.794199  1.748663  64.518109   77.257746
# 600036.XSHG    0.287384  0.727065  1.661832  66.967742   85.024840
# 600036.XSHG    0.289955  0.866944  1.593677  87.027798  112.539936
# 600036.XSHG    0.290393  1.028117  1.536520  89.206576  118.034119
# 600036.XSHG    0.289548  1.176240  1.485951  83.093771  113.375295
# 600036.XSHG    0.289309  1.226435  1.419402  80.306055  106.681682
# 600036.XSHG    0.288682  1.275783  1.405549  76.187378  107.779456
# 600036.XSHG    0.287443  1.225847  1.399348  73.734177  103.058995
# 600036.XSHG    0.288236  1.200800  1.404701  68.908555   99.041096
# 600036.XSHG    0.289128  1.232548  1.402613  76.273217  115.627190
# 600036.XSHG    0.289475  1.250778  1.406926  78.126852  120.350877
# 600036.XSHG    0.289494  1.281202  1.411632  80.806258  127.206946
# 600036.XSHG    0.287899  1.240560  1.418297  74.525589  121.523410
# 600036.XSHG    0.288490  1.319835  1.416771  90.903226  150.526316
# 600036.XSHG    0.288593  1.295073  1.400206  76.477404  125.159461
# 600036.XSHG    0.289276  1.286765  1.368528  73.628809  114.944042
# 600036.XSHG    0.289024  1.275314  1.347121  82.013970  132.952109
# 600036.XSHG    0.287801  1.247584  1.341951  78.038991  128.571429
# 600036.XSHG    0.286796  1.097525  1.351458  83.133971  137.985075
# 600036.XSHG    0.283088  0.954286  1.340898  74.311927  122.036262
# 600036.XSHG    0.281851  0.813799  1.335600  73.751452  108.738502
#
# [31 rows x 21 columns]

# %%
# Replace infinite updated data with nan
df.replace(to_replace=[np.inf, -np.inf], value=np.nan, inplace=True)

# 剔除含有 na 的行
df_dropna = df.dropna(axis=0, how='any')

# 选择特征列和标签列
df_dropna_y = df_dropna[['board_type', 'sector_code', 'month', 'date']]
df_dropna_features = df_dropna.loc[:, para.feature_column_start_name:para.feature_column_end_name]
df_dropna_features = pd.concat([df_dropna['yield_rate'], df_dropna_features], axis=1)

# 中位数去极值
df_dropna_features = df_dropna_features.clip(
    lower=df_dropna_features.median(axis=0) - 5 * df_dropna_features.mad(axis=0),
    upper=df_dropna_features.median(axis=0) + 5 * df_dropna_features.mad(axis=0),
    axis=1)

# 标准化
df_dropna_features = (df_dropna_features - df_dropna_features.mean()) / df_dropna_features.std(ddof=0)

# 拼接标签列和特征列
df_dropna_standard = pd.concat([df_dropna_y, df_dropna_features], axis=1)

# 写入文件
df_dropna_standard.to_csv(para.write_folder_path + '/0.csv')

print()
print('Done!')
# Out:
# Done!
