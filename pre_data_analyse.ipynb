# %%
import pandas as pd

df = pd.read_csv('data/cs_space_20d_rate_20d_2017_pre/0.csv', index_col='order_book_id')
df
# Out:
#               board_type            sector_code  month        date  \
# order_book_id
# 002080.XSHE    MainBoard              Materials      0  2017-01-03
# 600643.XSHG    MainBoard             Financials      0  2017-01-03
# 600997.XSHG    MainBoard                 Energy      0  2017-01-03
# 600662.XSHG    MainBoard            Industrials      0  2017-01-03
# 603606.XSHG    MainBoard            Industrials      0  2017-01-03
# ...                  ...                    ...    ...         ...
# 600356.XSHG    MainBoard              Materials      0  2017-01-03
# 002023.XSHE    MainBoard            Industrials      0  2017-01-03
# 002641.XSHE    MainBoard              Materials      0  2017-01-03
# 002371.XSHE    MainBoard  InformationTechnology      0  2017-01-03
# 002505.XSHE    MainBoard            Industrials      0  2017-01-03
#
#                yield_rate  ep_ratio_ttm  pb_ratio_ttm  sp_ratio_ttm  \
# order_book_id
# ...

# %%
import seaborn as sns

sns.histplot(df['yield_rate'])
# Out:
# <AxesSubplot:xlabel='yield_rate', ylabel='Count'>

# %%
df['yield_rate'].hist(bins=10);

# %%
df['yield_rate'].hist(bins=2)
# Out:
# <AxesSubplot:>
